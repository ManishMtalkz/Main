# %%
import pandas as pd
import json

# %%
df1 = pd.read_json('eventlogs.json')
df1.head()
# Out:
#                                     _id                            chatbot_id  \
# 0  {'$oid': '63a44c2899fbd802a6c748b9'}  {'$oid': '63a294b7e20457eac7473f25'}
# 1  {'$oid': '63a44c2899fbd802a6c748bb'}  {'$oid': '63a294b7e20457eac7473f25'}
# 2  {'$oid': '63a44c2899fbd802a6c748bc'}  {'$oid': '63a294b7e20457eac7473f25'}
# 3  {'$oid': '63a44c2899fbd802a6c748c3'}  {'$oid': '63a294b7e20457eac7473f25'}
# 4  {'$oid': '63a44c4699fbd802a6c748c8'}  {'$oid': '63a294b7e20457eac7473f25'}
#
#    uniq_id             event  \
# 0   589592       new_message
# 1   589592     session_start
# 2   589592   sending_message
# 3   589592  message_response
# 4   589592       new_message
#
#                                           properties      createdAt
# 0  {'chatbot_id': '63a294b7e20457eac7473f25', 'un...  1671711784792
# 1                                                NaN  1671711784794
# 2  {'chatbot_id': '63a294b7e20457eac7473f25', 'un...  1671711784795
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         49 non-null     object
#  1   chatbot_id  49 non-null     object
#  2   uniq_id     49 non-null     int64
#  3   event       49 non-null     object
#  4   properties  40 non-null     object
#  5   createdAt   49 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 2.4+ KB

# %%
dfprop = df1["properties"].apply(pd.Series)

# %%
dfprop.head(5)
# Out:
#                  chatbot_id uniq_id message_text   0 message flowchart  \
# 0  63a294b7e20457eac7473f25  589592           Hi NaN     NaN       NaN
# 1                       NaN     NaN          NaN NaN     NaN       NaN
# 2  63a294b7e20457eac7473f25  589592          NaN NaN   Start      None
# 3  63a294b7e20457eac7473f25  589592          NaN NaN     NaN      None
# 4  63a294b7e20457eac7473f25  589592           Hi NaN     NaN       NaN
#
#   instance_id flowchart_name properties
# 0         NaN            NaN        NaN
# 1         NaN            NaN        NaN
# 2         NaN            NaN        NaN
# 3         NaN            NaN        NaN
# 4         NaN            NaN        NaN

# %%
dfmessage = dfprop['message'].apply(pd.Series)
dfmessage
# Out:
#                               0   type  \
# 0                           NaN    NaN
# 1                           NaN    NaN
# 2                         Start    NaN
# 3                           NaN    NaN
# 4                           NaN    NaN
# 5   Sorry, I am still learning.    NaN
# 6                           NaN    NaN
# 7                           NaN    NaN
# 8      Thank you for your time.    NaN
# 9                           NaN    NaN
# 10                          NaN    NaN
# 11                          NaN    NaN
# 12                          NaN  reply
# 13                          NaN    NaN
# 14            I am tapping out.    NaN
# 15                          NaN    NaN
# 16                          NaN    NaN
# 17                          NaN    NaN
# 18                          NaN  reply
# 19                          NaN    NaN
# 20                          NaN    NaN
# 21                          NaN   list
# 22                          NaN    NaN
# ...

# %%
ex = df1['properties'].iloc[0]
print(ex)
type(ex)
# Out:
# {'chatbot_id': '63a294b7e20457eac7473f25', 'uniq_id': '589592', 'message_text': 'Hi'}
# dict

# %%
# df1.apply(lambda x: pd.Series(
#     json.loads(x['properties']).values(),
#     index=json.loads(x['properties']).keys()), 
#     axis=1)
